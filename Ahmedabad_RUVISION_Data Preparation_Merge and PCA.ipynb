# %%
import pandas as pd
import numpy as np

# %%
#Data Preparation for Model

# %%
Geo=pd.read_excel('C:/Users/Angshudeep Majumdar/Documents/Angshudeep Lappy/Ruvision/ERA5_mslp_2015-24_Daily data_Gujarat.xlsx')

# %%
rh= pd.read_excel('C:/Users/Angshudeep Majumdar/Documents/Angshudeep Lappy/Ruvision/ERA5_RH850_2015-24_Daily data_Gujarat.xlsx')

# %%
rh_1000= pd.read_excel('C:/Users/Angshudeep Majumdar/Documents/Angshudeep Lappy/Ruvision/ERA5_RH1000_2015-24_Daily data_Gujarat.xlsx')

# %%
rh_500= pd.read_excel('C:/Users/Angshudeep Majumdar/Documents/Angshudeep Lappy/Ruvision/ERA5_RH500_2015-24_Daily data_Gujarat.xlsx')

# %%
U= pd.read_excel(r'C:\Users\Angshudeep Majumdar\Documents\Angshudeep Lappy\Ruvision\ERA5_U10_2015-24_Daily data_Gujarat.xlsx')

# %%
V= pd.read_excel(r'C:\Users\Angshudeep Majumdar\Documents\Angshudeep Lappy\Ruvision\ERA5_V10_2015-24_Daily data_Gujarat.xlsx')

# %%
Temp= pd.read_excel(r'C:\Users\Angshudeep Majumdar\Documents\Angshudeep Lappy\Ruvision\ERA5_Temp2m_2015-24_Daily data_Gujarat.xlsx')

# %%
Prec= pd.read_excel('C:/Users/Angshudeep Majumdar/Documents/Angshudeep Lappy/Ruvision/ERA5_Acc_Prec_2015-24_Daily data_Gujarat.xlsx')

# %%
#Geo.set_index('DateTime', inplace=True)

# %%
rh.set_index('DateTime', inplace=True)

# %%
rh_1000.set_index('DateTime', inplace=True)

# %%
rh_500.set_index('DateTime', inplace=True)

# %%
U.set_index('DateTime', inplace=True)

# %%
V.set_index('DateTime', inplace=True)

# %%
Temp.set_index('DateTime', inplace=True)

# %%
Prec.set_index('DateTime', inplace=True)

# %%
Data_X= pd.concat([U, V, Temp], axis=1)

# %%
Data_X
# Out:
#             U10_17.5_65.0  U10_17.5_65.25  U10_17.5_65.5  U10_17.5_65.75  \
# DateTime
# 2015-01-01      -2.270376       -2.030996      -1.816885       -1.620596
# 2015-01-02      -3.279575       -3.158726      -3.011387       -2.817295
# 2015-01-03      -4.505812       -4.363478      -4.211744       -3.977491
# 2015-01-04      -5.436996       -5.404282      -5.373276       -5.306137
# 2015-01-05      -4.670731       -4.569290      -4.464676       -4.351151
# ...                   ...             ...            ...             ...
# 2024-12-27      -4.835665       -4.619967      -4.408297       -4.156343
# 2024-12-28      -4.413666       -4.308197      -4.227386       -4.117035
# 2024-12-29      -4.810490       -4.661564      -4.502262       -4.302433
# 2024-12-30      -2.840982       -2.600504      -2.371622       -2.117838
# 2024-12-31      -2.144810       -2.158360      -2.192661       -2.220127
#
#             U10_17.5_66.0  U10_17.5_66.25  U10_17.5_66.5  U10_17.5_66.75  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Fit and transform the data
data_X_scaled = scaler.fit_transform(Data_X)

# Convert the scaled array back to a DataFrame
data_X_normalized = pd.DataFrame(data_X_scaled, columns=Data_X.columns)

data_X_normalized
# Out:
#       Prec_17.5_65.0  Prec_17.5_65.25  Prec_17.5_65.5  Prec_17.5_65.75  \
# 0           0.000000         0.000000        0.000000         0.000000
# 1           0.001364         0.000239        0.000230         0.000261
# 2           0.003477         0.000359        0.000167         0.000147
# 3           0.000517         0.000203        0.000063         0.000073
# 4           0.000066         0.000335        0.000334         0.000000
# ...              ...              ...             ...              ...
# 3648        0.000000         0.000000        0.000000         0.000000
# 3649        0.000000         0.000000        0.000000         0.000000
# 3650        0.000000         0.000000        0.000000         0.000000
# 3651        0.000000         0.000000        0.000000         0.000000
# 3652        0.000000         0.000024        0.000000         0.000000
#
#       Prec_17.5_66.0  Prec_17.5_66.25  Prec_17.5_66.5  Prec_17.5_66.75  \
# ...

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(.99)

# %%
pca.fit(data_X_normalized)
# Out:
# PCA(n_components=0.99)

# %%
pca.n_components_
# Out:
# 199

# %%
PCA_data_X= pca.transform(data_X_normalized)

# %%
PCA_data_X
# Out:
# array([[-2.96604890e-01, -1.46155610e-02, -8.51625896e-02, ...,
#          7.47230939e-03,  4.79127479e-03, -9.73309421e-03],
#        [-3.59145333e-01, -1.30985534e-02, -1.25691888e-03, ...,
#          5.68628125e-03,  2.61265417e-03, -7.32278011e-04],
#        [-4.04900439e-01, -1.05268844e-02,  1.19319433e-02, ...,
#          7.34724119e-05,  7.12431740e-04, -2.16938210e-04],
#        ...,
#        [-4.10581824e-01, -1.89165705e-02,  4.77220334e-03, ...,
#         -3.38143179e-04, -1.54146705e-04,  5.34667912e-05],
#        [-4.14578001e-01, -1.93295784e-02,  9.04865722e-03, ...,
#          1.50165167e-06, -7.83232662e-04,  2.88249796e-04],
#        [-4.15124620e-01, -1.92894515e-02,  9.65599039e-03, ...,
#         -2.33847796e-05, -6.55176986e-04,  1.83019505e-04]])

# %%
transformed_data_X = pd.DataFrame(index = Data_X.index, data = PCA_data_X)

# %%
transformed_data_X
# Out:
#                  0         1         2         3         4         5    \
# DateTime
# 2015-01-01 -0.296605 -0.014616 -0.085163  0.022085  0.026872  0.044627
# 2015-01-02 -0.359145 -0.013099 -0.001257 -0.023667  0.044394  0.038198
# 2015-01-03 -0.404900 -0.010527  0.011932 -0.016555  0.045326 -0.004624
# 2015-01-04 -0.413992 -0.018171  0.009538 -0.016069  0.052618 -0.011758
# 2015-01-05 -0.414395 -0.017937  0.010858 -0.017981  0.052292 -0.011382
# ...              ...       ...       ...       ...       ...       ...
# 2024-12-27 -0.266352 -0.025503 -0.120630  0.012294 -0.047457  0.047052
# 2024-12-28 -0.375751 -0.010009 -0.028628  0.010412  0.039485  0.012903
# 2024-12-29 -0.410582 -0.018917  0.004772 -0.013862  0.052391 -0.007370
# 2024-12-30 -0.414578 -0.019330  0.009049 -0.016256  0.053521 -0.011143
# 2024-12-31 -0.415125 -0.019289  0.009656 -0.016465  0.053671 -0.011840
#
#                  6         7         8         9    ...       189       190  \
# ...

# %%
data_X_train= transformed_data_X.iloc[:3287,]

# %%
data_X_train
# Out:
#                   0         1         2         3         4         5   \
# DateTime
# 2015-01-01  4.393166  1.506216 -0.991583  0.815640 -0.757963  0.183233
# 2015-01-02  6.553175  0.679659 -0.195277  0.201709 -0.265556  0.047138
# 2015-01-03  7.797578  0.112000  0.258723 -0.140140  0.101126 -0.001488
# 2015-01-04  8.917852  0.551302  0.275076 -0.488537  0.094135  0.158723
# 2015-01-05  8.101538  0.488974  0.185910 -0.395089  0.046338  0.152161
# ...              ...       ...       ...       ...       ...       ...
# 2023-12-27  9.754311  0.117845  0.516942 -0.162940  0.150311 -0.010467
# 2023-12-28  7.695862  0.354486  0.309702 -0.312776  0.007710  0.076833
# 2023-12-29  7.183384  0.231032  0.351289 -0.381484  0.055824  0.073074
# 2023-12-30  7.020322  0.280282  0.150064 -0.045621 -0.063396  0.020459
# 2023-12-31  6.749361  0.544742 -0.105235  0.087801 -0.193965  0.085128
#
#                   6         7         8         9   ...        26        27  \
# ...

# %%
data_X_test= transformed_data_X.iloc[3287:,]

# %%
data_X_test
# Out:
#                    0         1         2         3         4         5   \
# DateTime
# 2024-01-01   7.259357  0.491242 -0.090447  0.218480 -0.186486  0.026248
# 2024-01-02   6.493041  0.424536 -0.196512  0.292861 -0.192760  0.003343
# 2024-01-03   5.864268  0.713215 -0.348848  0.103888 -0.258882  0.126270
# 2024-01-04   6.766918  0.710423 -0.322440  0.268218 -0.262474  0.081145
# 2024-01-05   7.009075  0.722874 -0.251449  0.102684 -0.209041  0.109635
# ...               ...       ...       ...       ...       ...       ...
# 2024-12-27   9.949120 -0.119215  0.428920  0.747883  0.091004 -0.144445
# 2024-12-28  10.261248  0.210106  0.233773  0.438202  0.037388 -0.093861
# 2024-12-29  10.617480  0.583195  0.277599 -0.048964  0.005778  0.050994
# 2024-12-30   9.833130  0.373523  0.418883 -0.257648  0.097169  0.067092
# 2024-12-31   9.731535  0.207721  0.507068 -0.309400  0.166876  0.050282
#
#                   6         7         8         9   ...        26        27  \
# ...

# %%
data_Y= pd.read_excel('C:/Users/Angshudeep Majumdar/Documents/Angshudeep Lappy/Ruvision/IMD_2015-2024_Daily Data_0.25 resolution Rain.xlsx')

# %%
data_Y
# Out:
#        DateTime  Prec_23.5_72.0  Prec_23.5_72.25  Prec_23.5_72.5  \
# 0    2015-01-01             0.0              0.0             0.0
# 1    2015-01-02             0.0              0.0             0.0
# 2    2015-01-03             0.0              0.0             0.0
# 3    2015-01-04             0.0              0.0             0.0
# 4    2015-01-05             0.0              0.0             0.0
# ...         ...             ...              ...             ...
# 3648 2024-12-27             0.0              0.0             0.0
# 3649 2024-12-28             0.0              0.0             0.0
# 3650 2024-12-29             0.0              0.0             0.0
# 3651 2024-12-30             0.0              0.0             0.0
# 3652 2024-12-31             0.0              0.0             0.0
#
#       Prec_23.5_72.75  Prec_23.5_73.0  Prec_23.25_72.0  Prec_23.25_72.25  \
# 0            0.000000        0.000000              0.0               0.0
# ...

# %%
data_Y.set_index('DateTime', inplace=True)

# %%
Y= data_Y['Prec_23.0_72.5']

# %%
data_Y_train= Y.iloc[:3287]

# %%
data_Y_train
# Out:
# DateTime
# 2015-01-01    0.000000
# 2015-01-02    0.527953
# 2015-01-03    0.000000
# 2015-01-04    0.000000
# 2015-01-05    0.000000
#                 ...
# 2023-12-27    0.000000
# 2023-12-28    0.000000
# 2023-12-29    0.000000
# 2023-12-30    0.000000
# 2023-12-31    0.000000
# Name: Prec_23.0_72.5, Length: 3287, dtype: float64

# %%
data_Y_test= Y.iloc[3287:]

# %%
data_Y_test
# Out:
# DateTime
# 2024-01-01    0.00000
# 2024-01-02    0.00000
# 2024-01-03    0.00000
# 2024-01-04    0.00000
# 2024-01-05    0.00000
#                ...
# 2024-12-27    0.17748
# 2024-12-28    0.00000
# 2024-12-29    0.00000
# 2024-12-30    0.00000
# 2024-12-31    0.00000
# Name: Prec_23.0_72.5, Length: 366, dtype: float64

# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
plt.figure(figsize=(8, 5))
plt.plot(range(1, len(pca.explained_variance_ratio_) + 1),
         pca.explained_variance_ratio_, marker='o', linestyle='--')
plt.title('Scree Plot')
plt.xlabel('Principal Component')
plt.ylabel('Variance')
plt.savefig("D:/Ruvision/Screeplot.png")

# %%
transformed_data_X.to_pickle('C:/Users/Angshudeep Majumdar/Documents/Angshudeep Lappy/Ruvision/Pickle format/transformed_dataX_Prec.pkl')

# %%
data_X_train.to_pickle('D:/Ruvision/Pickle format/data_X_train_mslp_prec.pkl')
data_X_test.to_pickle('D:/Ruvision/Pickle format/data_X_test_mslp_prec.pkl')

# %%
Y.to_pickle('D:/Ruvision/Obs_IMD_data.pkl')
